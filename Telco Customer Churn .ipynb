# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from matplotlib import style
import seaborn as sns

# %% [markdown]
# ## Exploratory Data Analysis(EDA)

# %%
df = pd.read_csv('Customer Churn.csv')

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %% [markdown]
# ## First step we Inspect the data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %% [markdown]
# ## 2nd Step Replace Blanks with 0 as tenure is 0 and total charges are recorded and change the type from object to float

# %%
df["TotalCharges"] = df["TotalCharges"].replace(" ","0")
df["TotalCharges"] = df["TotalCharges"].astype("float")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %% [markdown]
# ## 3rd step if there is null value

# %%
df.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# ## 4th Step to see descrition of data

# %%
df.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges  TotalCharges
# count    7043.000000  7043.000000     7043.000000   7043.000000
# mean        0.162147    32.371149       64.761692   2279.734304
# std         0.368612    24.559481       30.090047   2266.794470
# min         0.000000     0.000000       18.250000      0.000000
# 25%         0.000000     9.000000       35.500000    398.550000
# 50%         0.000000    29.000000       70.350000   1394.550000
# 75%         0.000000    55.000000       89.850000   3786.600000
# max         1.000000    72.000000      118.750000   8684.800000

# %% [markdown]
# ## 5th step Check Duplicate data in dataframe overall first and then unique row like customer id

# %%
df['customerID'].duplicated().sum()
# Out:
# 0

# %%
def conv(value):
    if value == 1:
        return "Yes"
    else:
        return "NO"

# %%
df['SeniorCitizen'] = df["SeniorCitizen"].apply(conv)

# %%
df.head(60)
# Out:
#     customerID  gender SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0   7590-VHVEG  Female            NO     Yes         No       1           No
# 1   5575-GNVDE    Male            NO      No         No      34          Yes
# 2   3668-QPYBK    Male            NO      No         No       2          Yes
# 3   7795-CFOCW    Male            NO      No         No      45           No
# 4   9237-HQITU  Female            NO      No         No       2          Yes
# 5   9305-CDSKC  Female            NO      No         No       8          Yes
# 6   1452-KIOVK    Male            NO      No        Yes      22          Yes
# 7   6713-OKOMC  Female            NO      No         No      10           No
# 8   7892-POOKP  Female            NO     Yes         No      28          Yes
# 9   6388-TABGU    Male            NO      No        Yes      62          Yes
# 10  9763-GRSKD    Male            NO     Yes        Yes      13          Yes
# ...

# %%
ax = sns.countplot(x = 'Churn', data = df)
ax.bar_label(ax.containers[0])
plt.title("count of Customer by Churns")
plt.show()

# %%
gb = df.groupby('Churn').agg({'Churn':'count'})

# %%
gb
# Out:
#        Churn
# Churn
# No      5174
# Yes     1869

# %%
plt.figure(figsize = (5,5))
plt.pie(gb['Churn'], labels = gb.index, autopct= "%1.2f%%")
plt.title("Percentage of Churn Customers")
plt.show()

# %% [markdown]
# ## From the pie chart we can conclude that 26.54% Customer has churn out

# %%
sns.countplot(x = "gender" , data = df, hue = "Churn")
plt.show()

# %%
gbg = df.groupby("gender").agg({"gender":"count"})

# %%
plt.pie(gbg["gender"], labels = gbg.index, autopct = "%1.2f%%")
plt.title("Churn by Gender")
plt.show()

# %%
ax = sns.countplot(x = "SeniorCitizen", data = df)
ax.bar_label(ax.containers[0])
plt.title("Count of Customers by Senior Citezen")
plt.show()

# %%
gb2 = df.groupby("SeniorCitizen").agg({"SeniorCitizen":"count"})
plt.pie(gb2["SeniorCitizen"], labels = gb2.index, autopct = "%1.2f%%")
plt.show()

# %% [markdown]
# ## It included that gender has nothing to do with churn out

# %%
gb1 = df.groupby("SeniorCitizen")['Churn'].value_counts(normalize = True).unstack() *100
fig, ax = plt.subplots(figsize=(6,6))
gb1.plot(kind = 'bar', stacked = True, ax=ax, color = ['#1f77b4', '#ff7f0e'])
for p in ax.patches:
    width,height = p.get_width(), p.get_height()
    x,y = p.get_xy()
    ax.text(x + width / 2, y + height / 2, f'{height:.2f}%' , ha = 'center', va= 'center')
plt.xlabel("SeniorCitizen ")
plt.ylabel("percentage %")
plt.title("Churn by Senior citizen(Stacked bar Chart)")
plt.legend(title = "Churn", bbox_to_anchor=(0.9,0.9))
plt.xticks(rotation = 0)
plt.show()

# %% [markdown]
# ## stacked bar chart shows how many senior citizens has churn out and how many young people has Churn out

# %%
plt.figure(figsize = (20,10))
sns.histplot(x = "tenure", data = df, bins = 50, hue= "Churn")

plt.show()

# %% [markdown]
# ## people who have used our services stayed for a long time they stayed basically Churn out happen in initial month like 0, 1

# %%
ax = sns.countplot(x = "Contract", data= df,hue = "Churn")
ax.bar_label(ax.containers[0])
ax.bar_label(ax.containers[1])
plt.title("Count of Customers by Contract")
plt.show()

# %% [markdown]
# ## people who have month to month contact are likely to churn than from those who have 1 or 2 years contract

# %%
df.columns.values
# Out:
# array(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection',
#        'TechSupport', 'StreamingTV', 'StreamingMovies', 'Contract',
#        'PaperlessBilling', 'PaymentMethod', 'MonthlyCharges',
#        'TotalCharges', 'Churn'], dtype=object)

# %%
columns = ['PhoneService', 'MultipleLines', 'InternetService', 
           'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 
           'TechSupport', 'StreamingTV', 'StreamingMovies']

# Create subplots
num_cols = 3  # Number of columns in the subplot grid
num_rows = (len(columns) + num_cols - 1) // num_cols  # Calculate rows needed

fig, axes = plt.subplots(num_rows, num_cols, figsize=(15, 10),)
axes = axes.flatten()  # Flatten the 2D array of axes

# Loop through the columns and create a countplot in each subplot
for i, column in enumerate(columns):
    sns.countplot(x=column, data=df, ax=axes[i], hue = df["Churn"])
    axes[i].set_title(column)
    axes[i].set_ylabel('Count')
    axes[i].set_xlabel('')  # Optionally remove x-labels for better aesthetics

# Hide any empty subplots
for j in range(i + 1, len(axes)):
    axes[j].set_visible(False)

plt.tight_layout()  # Adjust layout to prevent overlap
plt.show()

# %% [markdown]
# ## The data suggests that services like Fiber Optic Internet and lack of Tech Support or Online Security have higher churn rates. Services without internet or phone services tend to show less churn impact overall.

# %%
plt.figure(figsize=(9,4))
ax2 = sns.countplot(x = "PaymentMethod", data = df, hue = "Churn")
ax2.bar_label(ax2.containers[0])
ax2.bar_label(ax2.containers[1])
plt.xticks(rotation = 45)
plt.title("Churn vCustomer by Payment Method")
plt.show()

# %% [markdown]
# ### Customer is likely to Churn when he is using electronic check as a payment method

# %%
plt.figure(figsize=(9,4))
ax2 = sns.countplot(x = "PaperlessBilling", data = df, hue = "Churn")
ax2.bar_label(ax2.containers[0])
ax2.bar_label(ax2.containers[1])

plt.title("Churn vCustomer by Payment Method")
plt.show()
